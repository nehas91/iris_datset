# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as mp
import numpy as np

# %%
iris=pd.read_csv('downloads/iris.csv')

# %%
#let we check the shape of dtaset
print(iris.shape)
# Out:
# (150, 5)

# %%
#what are the name of the columns
print(iris.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# check it is balanced dataset or not
iris['species'].value_counts()
#datset is balanced
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
#analyze which feature is important 
#pair plots
sns.set_style('whitegrid')
mp.show()
sns.FacetGrid(iris,hue='species',size=4)\
.map(plt.scatter,'sepal_length','sepal_width')\
# Out:
#   File "<ipython-input-6-78534d4ab67c>", line 6
#     .map(plt.scatter,'sepal_length','sepal_width')\
#
# ^
# SyntaxError: unexpected EOF while parsing

# %%
# as per this scatter plot setosa  is linearly seprable
# on the basis of sepal len and sw
# but verginia and versicolor are overlapped
#pair plot
sns.set_style('whitegrid')
sns.pairplot(iris,hue='species',size=3)
mp.show()

# %%
iris_setosa=iris.loc[iris['species']=='setosa']
iris_virginica=iris.loc[iris['species']=='virginica']
iris_versicolor=iris.loc[iris['species']=='versicolor']

mp.plot(iris_setosa['petal_length'],np.zeros_like(iris_setosa['petal_length']),'o')
mp.plot(iris_virginica['petal_length'],np.zeros_like(iris_virginica['petal_length']),'o')
mp.plot(iris_versicolor['petal_length'],np.zeros_like(iris_versicolor['petal_length']),'o')
mp.show()

# %%
print("Means")
print(np.mean(iris_setosa['petal_length']))
#print(np.mean(np.append(iris_setosa[['petal_length']],50)))
#mean with outlier
print(np.mean(np.append(iris_setosa[['petal_length']],50)))
print(np.mean(iris_versicolor['petal_length']))
print(np.mean(iris_virginica['petal_length']))

print("\nStd-dev:");
print(np.std(iris_setosa["petal_length"]))
print(np.std(iris_virginica["petal_length"]))
print(np.std(iris_versicolor["petal_length"]))
# Out:
# Means
# 1.464
# 2.4156862745098038
# 4.26
# 5.552
#
# Std-dev:
# 0.17176728442867115
# 0.5463478745268441
# 0.4651881339845204

# %%
#PDF and CDF
count,bin_edges=np.histogram(iris_setosa['petal_length'],bins=10,density=True)
print(count)
print(bin_edges)
pdf=count/sum(count)
print(pdf)
cdf=np.cumsum(pdf)
print(cdf)
mp.plot(bin_edges[1:],pdf)
mp.plot(bin_edges[1:],cdf)

count,bin_edges=np.histogram(iris_virginica['petal_length'],bins=10,density=True)
print(count)
print(bin_edges)
pdf=count/sum(count)
print(pdf)
cdf=np.cumsum(pdf)
print(cdf)
mp.plot(bin_edges[1:],pdf)
mp.plot(bin_edges[1:],cdf)

count,bin_edges=np.histogram(iris_versicolor['petal_length'],bins=10,density=True)
print(count)
print(bin_edges)
pdf=count/sum(count)
print(pdf)
cdf=np.cumsum(pdf)
print(cdf)
mp.plot(bin_edges[1:],pdf)
mp.plot(bin_edges[1:],cdf)
# Out:
# [0.22222222 0.22222222 0.44444444 1.55555556 2.66666667 3.11111111
#  1.55555556 0.88888889 0.         0.44444444]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04]
# [0.02 0.04 0.08 0.22 0.46 0.74 0.88 0.96 0.96 1.  ]
# [0.08333333 0.41666667 1.         0.33333333 0.75       0.66666667
#  0.41666667 0.16666667 0.08333333 0.25      ]
# [4.5  4.74 4.98 5.22 5.46 5.7  5.94 6.18 6.42 6.66 6.9 ]
# [0.02 0.1  0.24 0.08 0.18 0.16 0.1  0.04 0.02 0.06]
# [0.02 0.12 0.36 0.44 0.62 0.78 0.88 0.92 0.94 1.  ]
# [0.0952381  0.19047619 0.28571429 0.19047619 0.76190476 0.66666667
#  0.57142857 0.95238095 0.66666667 0.38095238]
# [3.   3.21 3.42 3.63 3.84 4.05 4.26 4.47 4.68 4.89 5.1 ]
# [0.02 0.04 0.06 0.04 0.16 0.14 0.12 0.2  0.14 0.08]
# [0.02 0.06 0.12 0.16 0.32 0.46 0.58 0.78 0.92 1.  ]

# %%
import seaborn as sn
sn.FacetGrid(iris,hue='species',height=5).map(sn.distplot,'petal_length').add_legend();
mp.show();
sn.FacetGrid(iris,hue='species',height=5).map(sn.distplot,'petal_width').add_legend();
mp.show();
sn.FacetGrid(iris,hue='species',height=5).map(sn.distplot,'sepal_length').add_legend();
mp.show();
sn.FacetGrid(iris,hue='species',height=5).map(sn.distplot,'sepal_width').add_legend();
mp.show();

# %%
print("Means")
print(np.mean(iris_setosa['petal_length']))
#print(np.mean(np.append(iris_setosa[['petal_length']],50)))
#mean with outlier
print(np.mean(np.append(iris_setosa[['petal_length']],50)))
print(np.mean(iris_versicolor['petal_length']))
print(np.mean(iris_virginica['petal_length']))

print("\nStd-dev:");
print(np.std(iris_setosa["petal_length"]))
print(np.std(iris_virginica["petal_length"]))
print(np.std(iris_versicolor["petal_length"]))
# Out:
# Means
# 1.464
# 2.4156862745098038
# 4.26
# 5.552
#
# Std-dev:
# 0.17176728442867115
# 0.5463478745268441
# 0.4651881339845204

# %%
#mean Variance 
import numpy as np
print("\nMeadians:")
print(np.mean(iris_setosa['petal_length']))
#Median with Outlier
print(np.median(np.append(iris_setosa[['petal_length']],50)))
print(np.median(iris_versicolor['petal_length']))
print(np.median(iris_virginica['petal_length']))

print("Quantiles")
print(np.percentile(iris_setosa['petal_length'],np.arange(0,100,25)))
print(np.percentile(iris_virginica['petal_length'],np.arange(0,100,25)))
print(np.percentile(iris_versicolor['petal_length'],np.arange(0,100,25)))


print("90 Percentiles")
print(np.percentile(iris_setosa['petal_length'],90))
print(np.percentile(iris_virginica['petal_length'],90))
print(np.percentile(iris_versicolor['petal_length'],90))

from scipy import stats
#from statics import rabust
print("\nMedian Absolute Deviation")

#print(np.mean(np.append(iris_setosa[['petal_length']],50)))
#mean with outlier
print(stats.median_absolute_deviation(iris_setosa['petal_length']))
print(stats.median_absolute_deviation(iris_setosa['petal_length']))
print(stats.median_absolute_deviation(iris_setosa['petal_length']))
# Out:
# Meadians:
# 1.464
# 1.5
# 4.35
# 5.55
# Quantiles
# [1.    1.4   1.5   1.575]
# [4.5   5.1   5.55  5.875]
# [3.   4.   4.35 4.6 ]
# 90 Percentiles
# 1.7
# 6.3100000000000005
# 4.8
#
# Median Absolute Deviation
# 0.14826000000000011
# 0.14826000000000011
# 0.14826000000000011
# <ipython-input-31-3a5b93b25776>:27: DeprecationWarning: `median_absolute_deviation` is deprecated, use `median_abs_deviation` instead!
#
# To preserve the existing default behavior, use
# `scipy.stats.median_abs_deviation(..., scale=1/1.4826)`.
# The value 1.4826 is not numerically precise for scaling
# with a normal distribution. For a numerically precise value, use
# `scipy.stats.median_abs_deviation(..., scale='normal')`.
#
#   print(stats.median_absolute_deviation(iris_setosa['petal_length']))
# <ipython-input-31-3a5b93b25776>:28: DeprecationWarning: `median_absolute_deviation` is deprecated, use `median_abs_deviation` instead!
#
# To preserve the existing default behavior, use
# ...

# %%
sns.boxplot(x='species',y='petal_length', data=iris)
mp.show()

# %%
sn.violinplot(x='species',y='petal_length',data=iris,size=8)
mp.show()
